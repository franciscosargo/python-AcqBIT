# %%
import numpy as np
import h5py as h5
import os
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# Fetch created directory
path_name = os.path.join('~', 'Desktop', 'acqBIT')   
user_name = 'New User'
acquisition_folder = '20190225-011306'
device_name = 'HAND Device'

path = os.path.expanduser(os.path.join(path_name, user_name, acquisition_folder,device_name))

print path
list_files = os.listdir(path)
print list_files

acq_files = [os.path.join(path, path_file)  for path_file in list_files if '.h5' in path_file]
print acq_files
# Out:
# C:\Users\franciscosargo\Desktop\acqBIT\New User\20190225-011306\HAND Device
# ['201607181669_2019-02-25_01-13-09.h5', '201607181669_2019-02-25_01-13-09_profiling.txt']
# ['C:\\Users\\franciscosargo\\Desktop\\acqBIT\\New User\\20190225-011306\\HAND Device\\201607181669_2019-02-25_01-13-09.h5']

# %%
# Plot signals
channel_name = 'raw/channel_2'

for path_file in acq_files:
    with h5.File(path_file, 'r') as f:
        r_group = f[f.keys()[0]]
        channel_dset = r_group[channel_name]
        attrs = dict(channel_dset.attrs)
        channel = channel_dset[:]
        plt.figure(figsize=(15, 10))
        plt.plot(channel)

# %%
attrs
# Out:
# {u'label': 'A2', u'sensor': 'RAW', u'special': '{}'}
